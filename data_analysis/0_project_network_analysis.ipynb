# %% [markdown]
# # Data Source

# %% [markdown]
# 1. Local Authority Districts (May 2023): [Office for National Statistics - Local Authority Districts (May 2023) UK BFC](https://geoportal.statistics.gov.uk/datasets/ons::local-authority-districts-may-2023-uk-bfc-2/about) This file contains the digital vector boundaries for Local Authority Districts, in the United Kingdom, as at May 2023.
# 1. Regions (December 2022): [Office for National Statistics - Regions (December 2022) EN BFC](https://geoportal.statistics.gov.uk/datasets/ons::regions-december-2022-en-bfc/about) This file contains the digital vector boundaries for Regions in England as at December 2022.
# 1. AADF Data by direction - major roads: [Department of Transport - Road traffic statistic](https://roadtraffic.dft.gov.uk/downloads)   Number of vehicles that travel past the count point on an average day of the year, by direction of travel.
# 1. Major Roads Database - shape file format (2021): [Department of Transport - Road traffic statistic](https://roadtraffic.dft.gov.uk/downloads) 	Shape file of the major road network 2021.
# 1. Traffic Network data: OSM

# %% [markdown]
# # Network Analysis

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import networkx as nx
import osmnx as ox
from shapely.geometry import Polygon

# %%
network = gpd.read_file('./road_network/shp/MRDB_2021.shp')
network.plot()
# Out:
# <AxesSubplot:>

# %%
boundary = gpd.read_file('./road_network/shp/Regions_December_2022/RGN_DEC_2022_EN_BFC.shp')
london_boundary = boundary.query("RGN22NM=='London'")
london_boundary.to_file('./road_network/shp/london_boundary.shp')
london_boundary.plot()
# Out:
# <AxesSubplot:>

# %%
london_boundary.head()
# Out:
#      RGN22CD RGN22NM   BNG_E   BNG_N     LONG      LAT
# 6  E12000007  London  517515  178392 -0.30866  51.4923  \
#
#                                GlobalID
# 6  acffd85b-3f72-4c43-809d-ebe797270444  \
#
#                                             geometry
# 6  MULTIPOLYGON (((516122.679 172421.288, 516112....

# %%
london_boundary = gpd.read_file('./road_network/shp/london_boundary_fixed.shp')
london_boundary.plot()
# Out:
# <AxesSubplot:>

# %%
LAD_boundary = gpd.read_file('./road_network/shp/Local_Authority_Districts_May_2023/LAD_MAY_2023_UK_BFC.shp')
LAD_boundary.plot()
# Out:
# <AxesSubplot:>

# %%
london_lad = LAD_boundary.intersection(london_boundary.unary_union)
london_lad.plot()
# Out:
# C:\Users\29425\AppData\Roaming\Python\Python39\site-packages\shapely\set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# <AxesSubplot:>

# %%
london_network = gpd.overlay(network, london_boundary, how='intersection').to_crs("EPSG:4326")
m = folium.Map(location=[london_network.geometry.centroid.y.mean(), london_network.geometry.centroid.x.mean()], zoom_start=12)
folium.GeoJson(london_boundary).add_to(m)
m
# Out:
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\2539384881.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   m = folium.Map(location=[london_network.geometry.centroid.y.mean(), london_network.geometry.centroid.x.mean()], zoom_start=12)
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\2539384881.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   m = folium.Map(location=[london_network.geometry.centroid.y.mean(), london_network.geometry.centroid.x.mean()], zoom_start=12)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16dd1e33cb0e56a29e1073e9eb4308de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16dd1e33cb0e56a29e1073e9eb4308de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16dd1e33cb0e56a29e1073e9eb4308de = L.map(
#                 &quot;map_16dd1e33cb0e56a29e1073e9eb4308de&quot;,
#                 {
#                     center: [51.50475928882053, -0.12802001333584406],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf33fd5da333c09b24892baad58dec82 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16dd1e33cb0e56a29e1073e9eb4308de);
#
#
#
#         function geo_json_41ee70147b18aa659dff32129824e139_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_41ee70147b18aa659dff32129824e139 = L.geoJson(null, {
#                 onEachFeature: geo_json_41ee70147b18aa659dff32129824e139_onEachFeature,
#
#         });
#
#         function geo_json_41ee70147b18aa659dff32129824e139_add (data) {
#             geo_json_41ee70147b18aa659dff32129824e139
#                 .addData(data)
#                 .addTo(map_16dd1e33cb0e56a29e1073e9eb4308de);
#         }
#             geo_json_41ee70147b18aa659dff32129824e139_add({&quot;bbox&quot;: [-0.5103750741783117, 51.28676013323442, 0.33401550976699956, 51.691874137008085], &quot;features&quot;: [{&quot;bbox&quot;: [-0.5103750741783117, 51.28676013323442, 0.33401550976699956, 51.691874137008085], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-0.3177201595887312, 51.3936679934009], [-0.3182892403722032, 51.39331647409237], [-0.31853875749120575, 51.39317621721649], [-0.31879531089030366, 51.39304136183011], [-0.3190702488120444, 51.39291225951397], [-0.3193928392566192, 51.39277655157926], [-0.3198551995004038, 51.39259439354469], [-0.32006833172682697, 51.392544409738875], [-0.3204674914099218, 51.39247632290958], [-0.32074860114824094, 51.39241472536798], [-0.32093866429123274, 51.39236710714435], [-0.32123208637797834, 51.39228321085815], [-0.32161287256848003, 51.39220856218583], [-0.32208768089687234, 51.39211647240949], [-0.3223253436558086, 51.392063239668495], [-0.3237157586958948, 51.391695581578276], [-0.32461243789380717, 51.39150334778137], [-0.3248679916478668, 51.39147283880009], [-0.32561678282674594, 51.39143589650187], [-0.32569313758836177, 51.39143159200111], [-0.3258825478694243, 51.391440591087], [-0.3259900863156265, 51.391445720772076], [-0.3267236211099897, 51.391550591416404], [-0.3270847787061179, 51.391620474854186], [-0.32752531509331084, 51.39172034877328], [-0.3276091193878895, 51.39174582091436], [-0.32768721228568637, 51.39177210623902], [-0.32784005382194326, 51.39183811592223], [-0.3279810114512111, 51.39191474051293], [-0.3282296378003232, 51.392035249274066], [-0.3283916807175685, 51.392122064990666], [-0.32869391791622254, 51.39230976848765], [-0.3292128776069075, 51.392742573987825], [-0.32999728349796725, 51.393345469751154], [-0.3301518160569856, 51.39348252118438], [-0.33028048868400345, 51.39362009869108], [-0.33080814164953604, 51.39409167397229], [-0.3308760147261471, 51.394160964614976], [-0.3311266868613051, 51.3944603941691], [-0.3317407729561318, 51.395322549065256], [-0.3321211043695391, 51.39577215372682], [-0.3322855064440277, 51.39591841968005], [-0.3324846259631564, 51.39605520407143], [-0.33402902397406004, 51.397188676834716], [-0.33500896161885463, 51.39787163279952], [-0.33571403765377006, 51.39836898727451], [-0.3358287786298706, 51.39845701266399], [-0.3359872117886311, 51.39860489705331], [-0.33653672361693726, 51.39903261736989], [-0.3369528027014702, 51.39937123633444], [-0.33709368632548564, 51.399490193187965], [-0.3372269953323655, 51.39961884147009], [-0.3377245097383203, 51.40009175888671], [-0.3379277969544764, 51.40031399509343], [-0.33813525966796615, 51.400581327037344], [-0.33836360893025486, 51.40084882614559], [-0.3385023863705812, 51.40104160277295], [-0.3386325074499324, 51.40125830501781], [-0.3389731691872449, 51.40173618080034], [-0.3392031116353738, 51.40193640935695], [-0.33961027759701035, 51.402326132944346], [-0.3398027492199449, 51.40249067790898], [-0.34005177037880585, 51.402681284218254], [-0.3402454297760058, 51.40280988536029], [-0.34052976720121214, 51.40301717538937], [-0.34065783810682126, 51.403094501071166], [-0.34087806563722706, 51.40320648878652], [-0.3410169188703545, 51.40326419052778], [-0.34123231994103376, 51.403349045581315], [-0.34142708449268777, 51.403411138759935], [-0.3419289085304608, 51.40352791420234], [-0.34215312928014374, 51.40356893456346], [-0.34263052085337703, 51.40364670823609], [-0.3429190806412094, 51.403698432457546], [-0.34306308

# %%
geometry = london_network['geometry'].explode().reset_index(drop=True)
# Creating an empty undirected graph
G = nx.Graph()


# Adding edges to the road network
for line in geometry:
    coords = list(line.coords)
    for u, v in zip(coords[:-1], coords[1:]):
        G.add_edge(u, v)
# Out:
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\198125845.py:1: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   geometry = london_network['geometry'].explode().reset_index(drop=True)

# %%
# Plotting Network Graphics
nx.draw(G, node_size=10, node_color='blue', edge_color='gray')

plt.show()

# %%
# Get the degree distribution of a node
degree_freq = nx.degree_histogram(G)

degrees = range(3,6,1)
plt.bar(degrees, degree_freq[3:6])
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Node Degree Frequency of Main Road')
for i, freq in enumerate(degree_freq[3:6]):
    plt.text(i+3, freq, str(freq), ha='center', va='bottom')
plt.xticks(range(3, 6))
plt.show()

# %% [markdown]
# 数据显示，London Region范围内的主要道路网络中三向路口的数量是最多的，四向路口的数量排名第二，还有剩余少量的五向和六向路口。
# The data shows that the main road network within the London Region has the highest number of three-way junctions, with the second highest number of four-way junctions and a small number of remaining five-way and six-way junctions.

# %%
# Get the drive Network in London area from OSM
polygon = london_boundary.to_crs("EPSG:4326")
geometry = polygon['geometry']
polygon = Polygon(geometry.iloc[0].exterior)
graph = ox.graph_from_polygon(polygon, network_type="drive", simplify=True)

# %%
# 查看图的属性
print("Graph Attributes:")
print("Nodes:", graph.number_of_nodes())
print("Edges:", graph.number_of_edges())
print("Is Directed:", graph.is_directed())
print("Is MultiGraph:", graph.is_multigraph())
print("Is Weighted:", any("weight" in data for u, v, key, data in graph.edges(keys=True, data=True)))

# 如果图有节点属性，您可以像这样访问其中一个节点的属性：
if graph.number_of_nodes() > 0:
    node_id = next(iter(graph.nodes()))  # 获取第一个节点的ID
    node_attributes = graph.nodes[node_id]
    print("Attributes of Node", node_id, ":", node_attributes)

# 如果图有边属性，您可以像这样访问其中一条边的属性：
if graph.number_of_edges() > 0:
    edge = next(iter(graph.edges(keys=True, data=True)))  # 获取第一条边的信息
    edge_attributes = edge[3]  # 第四个元素是边的属性字典
    print("Attributes of Edge", edge[:2], ":", edge_attributes)
# Out:
# Graph Attributes:
# Nodes: 128336
# Edges: 299925
# Is Directed: True
# Is MultiGraph: True
# Is Weighted: False
# Attributes of Node 78112 : {'y': 51.526976, 'x': -0.1457924, 'street_count': 3}
# Attributes of Edge (78112, 25508583) : {'osmid': 129375498, 'name': 'Outer Circle', 'highway': 'unclassified', 'maxspeed': '20 mph', 'access': 'permissive', 'oneway': False, 'reversed': False, 'length': 19.391}

# %%
# Get the degree distribution of a node
degree_freq = nx.degree_histogram(graph)

degrees = range(3,6,1)
plt.bar(degrees, degree_freq[3:6])
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Node Degree Frequency of All Drive Road')
for i, freq in enumerate(degree_freq[3:6]):
    plt.text(i+3, freq, str(freq), ha='center', va='bottom')
plt.xticks(range(3, 6))
plt.show()

# %% [markdown]
# # Traffic Flow

# %%
csv = pd.read_csv("./road_network/dft_traffic_counts_aadf_by_direction.csv") # E12000007
csv.info()
csv.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965328 entries, 0 to 965327
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Count_point_id                965328 non-null  int64
#  1   Year                          965328 non-null  int64
#  2   Region_id                     965328 non-null  int64
#  3   Region_name                   965328 non-null  object
#  4   Region_ons_code               965328 non-null  object
#  5   Local_authority_id            965328 non-null  int64
#  6   Local_authority_name          965328 non-null  object
#  7   Local_authority_code          965328 non-null  object
#  8   Road_name                     965328 non-null  object
#  9   Road_category                 965328 non-null  object
#  10  Road_type                     965328 non-null  object
#  11  Start_junction_road_name      737095 non-null  object
#  12  End_junction_road_name        737112 non-null  object
#  13  Easting                       965328 non-null  int64
#  14  Northing                      965328 non-null  int64
#  15  Latitude                      965328 non-null  float64
#  16  Longitude                     965328 non-null  float64
#  17  Link_length_km                737787 non-null  float64
#  18  Link_length_miles             737787 non-null  float64
#  19  Estimation_method             965328 non-null  object
#  20  Estimation_method_detailed    965328 non-null  object
#  21  direction_of_travel           965290 non-null  object
#  22  Pedal_cycles                  965328 non-null  int64
#  23  Two_wheeled_motor_vehicles    965328 non-null  int64
#  24  Cars_and_taxis                965328 non-null  int64
#  25  Buses_and_coaches             965328 non-null  int64
#  26  LGVs                          965328 non-null  int64
#  27  HGVs_2_rigid_axle             965328 non-null  int64
#  28  HGVs_3_rigid_axle             965328 non-null  int64
#  29  HGVs_4_or_more_rigid_axle     965328 non-null  int64
#  30  HGVs_3_or_4_articulated_axle  965328 non-null  int64
#  31  HGVs_5_articulated_axle       965328 non-null  int64
#  32  HGVs_6_articulated_axle       965328 non-null  int64
#  33  All_HGVs                      965328 non-null  int64
#  34  All_motor_vehicles            965328 non-null  int64
# dtypes: float64(4), int64(19), object(12)
# memory usage: 257.8+ MB
#    Count_point_id  Year  Region_id               Region_name Region_ons_code
# 0           57093  2010          1                South West       E12000009  \
# 1           57094  2010          8  Yorkshire and the Humber       E12000003
# 2           57094  2010          8  Yorkshire and the Humber       E12000003
# 3           57095  2010          8  Yorkshire and the Humber       E12000003
# 4           57095  2010          8  Yorkshire and the Humber       E12000003
#
#    Local_authority_id                Local_authority_name
# 0                 139  Cornwall excluding Isles of Scilly  \
# 1                 130                  North Lincolnshire
# 2                 130                  North Lincolnshire
# 3                 169         Kingston upon Hull, City of
# 4                 169         Kingston upon Hull, City of
#
#   Local_authority_code Road_name Road_category  ... Buses_and_coaches  LGVs
# 0            E06000052     A3058            PA  ...                64   448  \
# 1            E06000013      A160            TA  ...                14   963
# 2            E06000013      A160            TA  ...                14   873
# 3            E06000010     A1165            PA  ...                19  1499
# 4            E06000010     A1165            PA  ...                24  1454
#
#   HGVs_2_rigid_axle  HGVs_3_rigid_axle  HGVs_4_or_more_rigid_axle
# 0                36                  3                          4  \
# 1               202                 87                        149
# 2               184                 93                        140
# 3               168                 54                         36
# 4               163                 44                         36
#
#    HGVs_3_or_4_articulated_axle  HGVs_5_articulated_axle
# 0                             2                        1  \
# 1                           165                      798
# 2                            65                      403
# 3                            21                       32
# 4                            14                       31
#
#    HGVs_6_articulated_axle  All_HGVs All_motor_vehicles
# 0                        1        47               3762
# 1                      730      2131               5659
# 2                     1427      2312               6045
# 3                       74       385               7041
# 4                       73       361               6229
#
# [5 rows x 35 columns]

# %%
london_road = csv.query("Region_ons_code=='E12000007' & Year==2021")
london_road.info()
london_road.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3806 entries, 482277 to 524173
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Count_point_id                3806 non-null   int64
#  1   Year                          3806 non-null   int64
#  2   Region_id                     3806 non-null   int64
#  3   Region_name                   3806 non-null   object
#  4   Region_ons_code               3806 non-null   object
#  5   Local_authority_id            3806 non-null   int64
#  6   Local_authority_name          3806 non-null   object
#  7   Local_authority_code          3806 non-null   object
#  8   Road_name                     3806 non-null   object
#  9   Road_category                 3806 non-null   object
#  10  Road_type                     3806 non-null   object
#  11  Start_junction_road_name      3382 non-null   object
#  12  End_junction_road_name        3382 non-null   object
#  13  Easting                       3806 non-null   int64
#  14  Northing                      3806 non-null   int64
#  15  Latitude                      3806 non-null   float64
#  16  Longitude                     3806 non-null   float64
#  17  Link_length_km                3386 non-null   float64
#  18  Link_length_miles             3386 non-null   float64
#  19  Estimation_method             3806 non-null   object
#  20  Estimation_method_detailed    3806 non-null   object
#  21  direction_of_travel           3806 non-null   object
#  22  Pedal_cycles                  3806 non-null   int64
#  23  Two_wheeled_motor_vehicles    3806 non-null   int64
#  24  Cars_and_taxis                3806 non-null   int64
#  25  Buses_and_coaches             3806 non-null   int64
#  26  LGVs                          3806 non-null   int64
#  27  HGVs_2_rigid_axle             3806 non-null   int64
#  28  HGVs_3_rigid_axle             3806 non-null   int64
#  29  HGVs_4_or_more_rigid_axle     3806 non-null   int64
#  30  HGVs_3_or_4_articulated_axle  3806 non-null   int64
#  31  HGVs_5_articulated_axle       3806 non-null   int64
#  32  HGVs_6_articulated_axle       3806 non-null   int64
#  33  All_HGVs                      3806 non-null   int64
#  34  All_motor_vehicles            3806 non-null   int64
# dtypes: float64(4), int64(19), object(12)
# memory usage: 1.0+ MB
#         Count_point_id  Year  Region_id Region_name Region_ons_code
# 482277            6000  2021          6      London       E12000007  \
# 482278            6000  2021          6      London       E12000007
# 482279            6001  2021          6      London       E12000007
# 482280            6001  2021          6      London       E12000007
# 482295            6013  2021          6      London       E12000007
#
#         Local_authority_id Local_authority_name Local_authority_code
# 482277                  57               Barnet            E09000003  \
# 482278                  57               Barnet            E09000003
# 482279                  57               Barnet            E09000003
# 482280                  57               Barnet            E09000003
# 482295                  66           Hillingdon            E09000017
#
#        Road_name Road_category  ... Buses_and_coaches  LGVs HGVs_2_rigid_axle
# 482277        M1            TM  ...               145  5521              1430  \
# 482278        M1            TM  ...               174  4360              1062
# 482279        M1            TM  ...                26  5434               786
# 482280        M1            TM  ...                28  6576               829
# 482295        M4            TM  ...               250  7461              1516
#
#         HGVs_3_rigid_axle  HGVs_4_or_more_rigid_axle
# 482277                112                        208  \
# 482278                 92                        279
# 482279                130                        189
# 482280                129                        200
# 482295                180                        573
#
#         HGVs_3_or_4_articulated_axle  HGVs_5_articulated_axle
# 482277                            64                      104  \
# 482278                           132                      130
# 482279                            49                      132
# 482280                            48                      110
# 482295                            75                      154
#
#         HGVs_6_articulated_axle  All_HGVs All_motor_vehicles
# 482277                      421      2339              22518
# 482278                      516      2211              21947
# 482279                      785      2072              31779
# 482280                      492      1808              33197
# 482295                      803      3301              53935
#
# [5 rows x 35 columns]

# %%
london_road["All_vehicles"] = london_road["All_HGVs"] + london_road["All_motor_vehicles"]
london_road.info()
london_road.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3806 entries, 482277 to 524173
# Data columns (total 36 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Count_point_id                3806 non-null   int64
#  1   Year                          3806 non-null   int64
#  2   Region_id                     3806 non-null   int64
#  3   Region_name                   3806 non-null   object
#  4   Region_ons_code               3806 non-null   object
#  5   Local_authority_id            3806 non-null   int64
#  6   Local_authority_name          3806 non-null   object
#  7   Local_authority_code          3806 non-null   object
#  8   Road_name                     3806 non-null   object
#  9   Road_category                 3806 non-null   object
#  10  Road_type                     3806 non-null   object
#  11  Start_junction_road_name      3382 non-null   object
#  12  End_junction_road_name        3382 non-null   object
#  13  Easting                       3806 non-null   int64
#  14  Northing                      3806 non-null   int64
#  15  Latitude                      3806 non-null   float64
#  16  Longitude                     3806 non-null   float64
#  17  Link_length_km                3386 non-null   float64
#  18  Link_length_miles             3386 non-null   float64
#  19  Estimation_method             3806 non-null   object
#  20  Estimation_method_detailed    3806 non-null   object
#  21  direction_of_travel           3806 non-null   object
#  22  Pedal_cycles                  3806 non-null   int64
#  23  Two_wheeled_motor_vehicles    3806 non-null   int64
#  24  Cars_and_taxis                3806 non-null   int64
#  25  Buses_and_coaches             3806 non-null   int64
#  26  LGVs                          3806 non-null   int64
#  27  HGVs_2_rigid_axle             3806 non-null   int64
#  28  HGVs_3_rigid_axle             3806 non-null   int64
#  29  HGVs_4_or_more_rigid_axle     3806 non-null   int64
#  30  HGVs_3_or_4_articulated_axle  3806 non-null   int64
#  31  HGVs_5_articulated_axle       3806 non-null   int64
#  32  HGVs_6_articulated_axle       3806 non-null   int64
#  33  All_HGVs                      3806 non-null   int64
#  34  All_motor_vehicles            3806 non-null   int64
#  35  All_vehicles                  3806 non-null   int64
# dtypes: float64(4), int64(20), object(12)
# memory usage: 1.1+ MB
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\2168367199.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   london_road["All_vehicles"] = london_road["All_HGVs"] + london_road["All_motor_vehicles"]
#         Count_point_id  Year  Region_id Region_name Region_ons_code
# 482277            6000  2021          6      London       E12000007  \
# 482278            6000  2021          6      London       E12000007
# 482279            6001  2021          6      London       E12000007
# 482280            6001  2021          6      London       E12000007
# 482295            6013  2021          6      London       E12000007
#
#         Local_authority_id Local_authority_name Local_authority_code
# 482277                  57               Barnet            E09000003  \
# 482278                  57               Barnet            E09000003
# 482279                  57               Barnet            E09000003
# 482280                  57               Barnet            E09000003
# 482295                  66           Hillingdon            E09000017
#
#        Road_name Road_category  ...  LGVs HGVs_2_rigid_axle HGVs_3_rigid_axle
# 482277        M1            TM  ...  5521              1430               112  \
# 482278        M1            TM  ...  4360              1062                92
# 482279        M1            TM  ...  5434               786               130
# 482280        M1            TM  ...  6576               829               129
# 482295        M4            TM  ...  7461              1516               180
#
#         HGVs_4_or_more_rigid_axle  HGVs_3_or_4_articulated_axle
# 482277                        208                            64  \
# 482278                        279                           132
# 482279                        189                            49
# 482280                        200                            48
# 482295                        573                            75
#
#         HGVs_5_articulated_axle  HGVs_6_articulated_axle  All_HGVs
# 482277                      104                      421      2339  \
# 482278                      130                      516      2211
# 482279                      132                      785      2072
# 482280                      110                      492      1808
# 482295                      154                      803      3301
#
#         All_motor_vehicles All_vehicles
# 482277               22518        24857
# 482278               21947        24158
# 482279               31779        33851
# 482280               33197        35005
# 482295               53935        57236
#
# [5 rows x 36 columns]

# %%
# linear normalized the vehicles
london_road["all_vehicles_normalized"] = (london_road["All_vehicles"] - london_road["All_vehicles"].min()) / (london_road["All_vehicles"].max() - london_road["All_vehicles"].min())
london_road.info()
london_road.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3806 entries, 482277 to 524173
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Count_point_id                3806 non-null   int64
#  1   Year                          3806 non-null   int64
#  2   Region_id                     3806 non-null   int64
#  3   Region_name                   3806 non-null   object
#  4   Region_ons_code               3806 non-null   object
#  5   Local_authority_id            3806 non-null   int64
#  6   Local_authority_name          3806 non-null   object
#  7   Local_authority_code          3806 non-null   object
#  8   Road_name                     3806 non-null   object
#  9   Road_category                 3806 non-null   object
#  10  Road_type                     3806 non-null   object
#  11  Start_junction_road_name      3382 non-null   object
#  12  End_junction_road_name        3382 non-null   object
#  13  Easting                       3806 non-null   int64
#  14  Northing                      3806 non-null   int64
#  15  Latitude                      3806 non-null   float64
#  16  Longitude                     3806 non-null   float64
#  17  Link_length_km                3386 non-null   float64
#  18  Link_length_miles             3386 non-null   float64
#  19  Estimation_method             3806 non-null   object
#  20  Estimation_method_detailed    3806 non-null   object
#  21  direction_of_travel           3806 non-null   object
#  22  Pedal_cycles                  3806 non-null   int64
#  23  Two_wheeled_motor_vehicles    3806 non-null   int64
#  24  Cars_and_taxis                3806 non-null   int64
#  25  Buses_and_coaches             3806 non-null   int64
#  26  LGVs                          3806 non-null   int64
#  27  HGVs_2_rigid_axle             3806 non-null   int64
#  28  HGVs_3_rigid_axle             3806 non-null   int64
#  29  HGVs_4_or_more_rigid_axle     3806 non-null   int64
#  30  HGVs_3_or_4_articulated_axle  3806 non-null   int64
#  31  HGVs_5_articulated_axle       3806 non-null   int64
#  32  HGVs_6_articulated_axle       3806 non-null   int64
#  33  All_HGVs                      3806 non-null   int64
#  34  All_motor_vehicles            3806 non-null   int64
#  35  All_vehicles                  3806 non-null   int64
#  36  all_vehicles_normalized       3806 non-null   float64
# dtypes: float64(5), int64(20), object(12)
# memory usage: 1.1+ MB
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\1360467440.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   london_road["all_vehicles_normalized"] = (london_road["All_vehicles"] - london_road["All_vehicles"].min()) / (london_road["All_vehicles"].max() - london_road["All_vehicles"].min())
#         Count_point_id  Year  Region_id Region_name Region_ons_code
# 482277            6000  2021          6      London       E12000007  \
# 482278            6000  2021          6      London       E12000007
# 482279            6001  2021          6      London       E12000007
# 482280            6001  2021          6      London       E12000007
# 482295            6013  2021          6      London       E12000007
#
#         Local_authority_id Local_authority_name Local_authority_code
# 482277                  57               Barnet            E09000003  \
# 482278                  57               Barnet            E09000003
# 482279                  57               Barnet            E09000003
# 482280                  57               Barnet            E09000003
# 482295                  66           Hillingdon            E09000017
#
#        Road_name Road_category  ... HGVs_2_rigid_axle HGVs_3_rigid_axle
# 482277        M1            TM  ...              1430               112  \
# 482278        M1            TM  ...              1062                92
# 482279        M1            TM  ...               786               130
# 482280        M1            TM  ...               829               129
# 482295        M4            TM  ...              1516               180
#
#        HGVs_4_or_more_rigid_axle  HGVs_3_or_4_articulated_axle
# 482277                       208                            64  \
# 482278                       279                           132
# 482279                       189                            49
# 482280                       200                            48
# 482295                       573                            75
#
#         HGVs_5_articulated_axle  HGVs_6_articulated_axle  All_HGVs
# 482277                      104                      421      2339  \
# 482278                      130                      516      2211
# 482279                      132                      785      2072
# 482280                      110                      492      1808
# 482295                      154                      803      3301
#
#         All_motor_vehicles  All_vehicles all_vehicles_normalized
# 482277               22518         24857                0.243491
# 482278               21947         24158                0.236644
# 482279               31779         33851                0.331593
# 482280               33197         35005                0.342897
# 482295               53935         57236                0.560665
#
# [5 rows x 37 columns]

# %% [markdown]
# The Sample intersection located at the south-east of Hyde park
# ![image-2.png](attachment:image-2.png)
#
# Road count point id and name is:
#
# |Position|Count point id|Name|
# |--|--|--|
# |North-S1|7044|A400|
# |South-S1|37101|A400|
# |East-S1|76054|A501|
# |West-S1|47245|A501|
# |North-S2|56990|A4200|
# |South-S2|90230|A4200|
# |East-S2|56815|A501|
# |West-S2|17169|A501|

# %%
sample_intersection = london_road[london_road['Count_point_id'].isin([7044, 37101, 76054, 47245, 56990, 90230, 56815, 17169])]
sample_intersection["direction"] = sample_intersection["direction_of_travel"]
# sample_intersection.info()
sample_intersection.head(20)
# Out:
# C:\Users\29425\AppData\Local\Temp\ipykernel_17500\4138503609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_intersection["direction"] = sample_intersection["direction_of_travel"]
#         Count_point_id  Year  Region_id Region_name Region_ons_code
# 483369            7044  2021          6      London       E12000007  \
# 483370            7044  2021          6      London       E12000007
# 487071           17169  2021          6      London       E12000007
# 487072           17169  2021          6      London       E12000007
# 493907           37101  2021          6      London       E12000007
# 497499           47245  2021          6      London       E12000007
# 497500           47245  2021          6      London       E12000007
# 500705           56815  2021          6      London       E12000007
# 500706           56815  2021          6      London       E12000007
# 500951           56990  2021          6      London       E12000007
# 500952           56990  2021          6      London       E12000007
# 506538           76054  2021          6      London       E12000007
# 506539           76054  2021          6      London       E12000007
# 512606           90230  2021          6      London       E12000007
# 512607           90230  2021          6      London       E12000007
#
#         Local_authority_id Local_authority_name Local_authority_code
# 483369                 145               Camden            E09000007  \
# 483370                 145               Camden            E09000007
# 487071                 145               Camden            E09000007
# 487072                 145               Camden            E09000007
# 493907                 145               Camden            E09000007
# 497499                 145               Camden            E09000007
# 497500                 145               Camden            E09000007
# 500705                 145               Camden            E09000007
# 500706                 145               Camden            E09000007
# 500951                 145               Camden            E09000007
# 500952                 145               Camden            E09000007
# 506538                 145               Camden            E09000007
# 506539                 145               Camden            E09000007
# 512606                 145               Camden            E09000007
# 512607                 145               Camden            E09000007
#
#        Road_name Road_category  ... HGVs_3_rigid_axle
# 483369      A400            PA  ...                32  \
# 483370      A400            PA  ...                28
# 487071      A501            PA  ...                60
# 487072      A501            PA  ...                51
# 493907      A400            PA  ...                59
# 497499      A501            PA  ...                97
# 497500      A501            PA  ...               123
# 500705      A501            PA  ...                56
# 500706      A501            PA  ...                56
# 500951     A4200            PA  ...                21
# 500952     A4200            PA  ...                17
# 506538      A501            PA  ...                62
# 506539      A501            PA  ...                57
# 512606     A4200            PA  ...                26
# 512607     A4200            PA  ...                24
#
#        HGVs_4_or_more_rigid_axle HGVs_3_or_4_articulated_axle
# 483369                        66                           16  \
# 483370                        68                           11
# 487071                        89                           22
# 487072                        70                           26
# 493907                        76                           17
# 497499                       306                           26
# 497500                       311                           16
# 500705                       226                           29
# 500706                       200                           16
# 500951                        21                            1
# 500952                        16                            1
# 506538                        72                           25
# 506539                        71                           16
# 512606                       100                            7
# 512607                        54                           11
#
#         HGVs_5_articulated_axle  HGVs_6_articulated_axle  All_HGVs
# 483369                        6                       15       283  \
# 483370                        6                       15       261
# 487071                       40                       30       709
# 487072                       32                       16       610
# 493907                       10                        4       624
# 497499                       10                       69      1463
# 497500                       17                       54      1512
# 500705                       16                       59       938
# 500706                        8                       46       883
# 500951                        2                        2       142
# 500952                        0                        2        86
# 506538                       38                       28       540
# 506539                       24                       19       600
# 512606                        7                        9       416
# 512607                        7                        9       395
#
#         All_motor_vehicles  All_vehicles  all_vehicles_normalized direction
# 483369                6611          6894                 0.067531         N
# 483370                9839         10100                 0.098936         S
# 487071               29734         30443                 0.298209         E
# 487072               23737         24347                 0.238495         W
# 493907               10488         11112                 0.108849         N
# 497499               31712         33175                 0.324971         E
# 497500               30271         31783                 0.311336         W
# 500705               21550         22488                 0.220285         E
# 500706               21960         22843                 0.223762         W
# 500951                5919          6061                 0.059372         N
# 500952                3296          3382                 0.033129         S
# 506538               27301         27841                 0.272721         E
# 506539               19495         20095                 0.196844         W
# 512606                9808         10224                 0.100151         N
# 512607               10473         10868                 0.106459         S
#
# [15 rows x 38 columns]

# %% [markdown]
# Focusing only on the in-flow traffic without considering the turning of vehicles, the final obtained flow is:
#
# |Position|Count point id|Name|Direction|Flow|Simple flow|
# |--|--|--|--|--|--|
# |North-S1|7044|A400|S|0.098936|0.10|
# |South-S1|37101|A400|N|0.108849|0.11|
# |West-S1|47245|A501|E|0.324971|0.32|
# |--|--|--|--|--|--|
# |North-S2|56990|A4200|N|0.059372|0.06|
# |South-S2|90230|A4200|N|0.100151|0.10|
# |East-S2|56815|A501|E|0.220285|0.22|
# |West-S2|17169|A501|W|0.238495|0.24|
# |North-S2|56990|A4200|S|0.033129|0.03|
# |South-S2|90230|A4200|S|0.106459|0.11|
# |East-S2|56815|A501|W|0.223762|0.22|
# |West-S2|17169|A501|E|0.298209|0.30|
